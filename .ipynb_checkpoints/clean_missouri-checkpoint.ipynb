# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("/Users/ashlynohara/Desktop/cleanmopython/cleanmissouri/data.csv")
# Out:
#       county_name precinct_name                    office_title  \
# 0           Adair   SOUTHWEST 1     State Senator - District 18
# 1           Adair   SOUTHEAST 2     State Senator - District 18
# 2           Adair   SOUTHEAST 3     State Senator - District 18
# 3           Adair   SOUTHEAST 4     State Senator - District 18
# 4           Adair   NORTHEAST 5     State Senator - District 18
# ...           ...           ...                             ...
# 13698      Wright     HARTVILLE  Constitutional Amendment No. 1
# 13699      Wright  LITTLE CREEK  Constitutional Amendment No. 1
# 13700      Wright         MANES  Constitutional Amendment No. 1
# 13701      Wright   GROVESPRING  Constitutional Amendment No. 1
# 13702      Wright      ABSENTEE  Constitutional Amendment No. 1
#
#       candidate_ballot_name  yes_votes  no_votes  Unnamed: 6  Unnamed: 7
# 0          Cindy O'Laughlin        283       NaN         NaN         NaN
# ...

# %%
original_data = pd.read_csv("/Users/ashlynohara/Desktop/cleanmopython/cleanmissouri/data.csv")

# %%
no_absentee = original_data.loc[original_data['precinct_name'] != 'ABSENTEE']

# %%
no_federal = no_absentee.loc[(no_absentee['precinct_name'] != 'FEDERAL')]

# %%
no_provisional = no_federal.loc[(no_absentee['precinct_name'] != 'PROVISIONAL')]

# %%
house1 = no_provisional[(no_provisional['office_title'] == 'State Representative - District 1')
                       | (no_provisional['office_title'] == 'Constitutional Amendment No. 1')]

# %%
house1
# Out:
#       county_name precinct_name                    office_title  \
# 60          Adair   SOUTHWEST 1  Constitutional Amendment No. 1
# 61          Adair   SOUTHEAST 2  Constitutional Amendment No. 1
# 62          Adair   SOUTHEAST 3  Constitutional Amendment No. 1
# 63          Adair   SOUTHEAST 4  Constitutional Amendment No. 1
# 64          Adair   NORTHEAST 5  Constitutional Amendment No. 1
# ...           ...           ...                             ...
# 13697      Wright      FAIRVIEW  Constitutional Amendment No. 1
# 13698      Wright     HARTVILLE  Constitutional Amendment No. 1
# 13699      Wright  LITTLE CREEK  Constitutional Amendment No. 1
# 13700      Wright         MANES  Constitutional Amendment No. 1
# 13701      Wright   GROVESPRING  Constitutional Amendment No. 1
#
#       candidate_ballot_name  yes_votes  no_votes  Unnamed: 6  Unnamed: 7
# 60                      NaN        342     159.0         NaN      4563.0
# ...

# %%
onehouse = house1[(house1['county_name'] == "Atchison")
                | (house1['county_name'] == "Holt")
                | (house1['county_name'] == "Nodaway")
                | (house1['county_name'] == "Worth")
               ]

# %%
onecandidate = onehouse[(onehouse['candidate_ballot_name'] != "Paul Taylor")]

# %%
onecandidate
# Out:
#       county_name   precinct_name                       office_title  \
# 144      Atchison          TARKIO  State Representative - District 1
# 145      Atchison       ROCK PORT  State Representative - District 1
# 146      Atchison         FAIRFAX  State Representative - District 1
# 147      Atchison        WESTBORO  State Representative - District 1
# 148      Atchison          WATSON  State Representative - District 1
# ...           ...             ...                                ...
# 13677       Worth          GREENE     Constitutional Amendment No. 1
# 13678       Worth     MIDDLE FORK     Constitutional Amendment No. 1
# 13679       Worth           SMITH     Constitutional Amendment No. 1
# 13680       Worth  WEST FLETCHALL     Constitutional Amendment No. 1
# 13681       Worth      WEST UNION     Constitutional Amendment No. 1
#
#       candidate_ballot_name  yes_votes  no_votes  Unnamed: 6  Unnamed: 7
# ...

# %%
onejusta1 = onecandidate[(onecandidate['office_title'] == "Constitutional Amendment No. 1")]

# %%
onejusta1.yes_votes.sum()
# Out:
# 5863

# %%
h1yes = onejusta1.yes_votes.sum()

# %%
onejusta1.no_votes.sum()
# Out:
# 5661.0

# %%
h1no = onejusta1.no_votes.sum()

# %%
house_district1_percentage = h1yes / (h1yes + h1no)

# %%
house_district1_percentage * 100
# Out:
# 50.876431794515796

# %%
pd.set_option('display.max_rows', None)

# %%
house158 = no_provisional[(no_provisional['office_title'] == 'State Representative - District 158')
                       | (no_provisional['office_title'] == 'Constitutional Amendment No. 1')]

# %%
onefiftyeighthouse = house158[
                (house158['county_name'] == "Barry")
                | (house158['county_name'] == "Lawrence")
               ]

# %%
onefiftyeighthouse
# Out:
#      county_name                 precinct_name  \
# 242        Barry                        EXETER
# 243        Barry                       JENKINS
# 244        Barry                        MONETT
# 245        Barry                 ROARING RIVER
# 246        Barry                       WHEATON
# 247        Barry                        GOLDEN
# 248        Barry                    SHELL KNOB
# 249        Barry                      SELIGMAN
# 250        Barry                CASSVILLE-CITY
# 251        Barry          BUTTERFIELD/MCDONALD
# 252        Barry       CASSVILLE RURAL/MINERAL
# 253        Barry  KINGS PRAIRIE/PLEASANT RIDGE
# 254        Barry      MONETT RURAL/CAPPS CREEK
# 255        Barry             OZARK/CRANE CREEK
# 256        Barry                PURDY/MCDOWELL
# 257        Barry                  WASHBURN/ASH
# 259        Barry                        EXETER
# 260        Barry                       JENKINS
# 261        Barry                        MONETT
# ...

# %%
onefiftyeightjusta1 = onefiftyeighthouse[(onefiftyeighthouse['office_title'] == "Constitutional Amendment No. 1")]

# %%
onefiftyeightjusta1
# Out:
#      county_name                 precinct_name  \
# 259        Barry                        EXETER
# 260        Barry                       JENKINS
# 261        Barry                        MONETT
# 262        Barry                 ROARING RIVER
# 263        Barry                       WHEATON
# 264        Barry                        GOLDEN
# 265        Barry                    SHELL KNOB
# 266        Barry                      SELIGMAN
# 267        Barry                CASSVILLE-CITY
# 268        Barry          BUTTERFIELD/MCDONALD
# 269        Barry       CASSVILLE RURAL/MINERAL
# 270        Barry  KINGS PRAIRIE/PLEASANT RIDGE
# 271        Barry      MONETT RURAL/CAPPS CREEK
# 272        Barry             OZARK/CRANE CREEK
# 273        Barry                PURDY/MCDOWELL
# 274        Barry                  WASHBURN/ASH
# 6245    Lawrence                     SW AURORA
# 6246    Lawrence                     SE AURORA
# 6247    Lawrence                      N AURORA
# ...

# %%
onefiftyeightjusta1.yes_votes.sum()
# Out:
# 13139

# %%
h158yes = onefiftyeightjusta1.yes_votes.sum()

# %%
onefiftyeightjusta1.no_votes.sum()
# Out:
# 10583.0

# %%
h158no = onefiftyeightjusta1.no_votes.sum()

# %%
house_district158_percentage = h158yes / (h158yes + h158no)

# %%
house_district158_percentage * 100
# Out:
# 55.387404097462266

# %%
cedartest = no_provisional[(no_provisional['county_name'] == 'Cedar')
                        & (no_provisional['office_title'] == 'State Representative - District 128')

                    ]

# %%
cedartest
# Out:
#      county_name            precinct_name  \
# 1630       Cedar                JEFFERSON
# 1631       Cedar     MADISON - BEAR CREEK
# 1632       Cedar  BENTON - JERICO SPRINGS
# 1633       Cedar               SOUTH LINN
# 1634       Cedar               NORTH LINN
# 1635       Cedar               WASHINGTON
# 1637       Cedar                JEFFERSON
# 1638       Cedar     MADISON - BEAR CREEK
# 1639       Cedar  BENTON - JERICO SPRINGS
# 1640       Cedar               SOUTH LINN
# 1641       Cedar               NORTH LINN
# 1642       Cedar               WASHINGTON
#
#                              office_title candidate_ballot_name  yes_votes  \
# 1630  State Representative - District 128         Mike Stephens        227
# 1631  State Representative - District 128         Mike Stephens        129
# 1632  State Representative - District 128         Mike Stephens        174
# 1633  State Representative - District 128         Mike Stephens        540
# ...

# %%
cedartest1 = cedartest[(cedartest['office_title'] == 'State Representative - District 127')]
# Out:
# Empty DataFrame
# Columns: [county_name, precinct_name, office_title, candidate_ballot_name, yes_votes, no_votes, Unnamed: 6, Unnamed: 7]
# Index: []

# %%
onecantest = cedartest[(cedartest['candidate_ballot_name'] == 'Ann Kelley')
                      | (cedartest['candidate_ballot_name'] == 'Warren D. Love')
                      | (cedartest['candidate_ballot_name'] == 'Mike Stephens')
                      ]

# %%
onecantest
# Out:
#      county_name                     precinct_name  \
# 277       Barton           BARTON CITY/LEROY/OZARK
# 278       Barton       CENTRAL/NASHVILLE/NORTHFORK
# 279       Barton                        CITY 1 & 2
# 280       Barton                        CITY 3 & 4
# 281       Barton  DOYLESPORT/MILFORD/NEWPORT/UNION
# 282       Barton                       GOLDEN CITY
# 283       Barton                    LAMAR/RICHLAND
# 284       Barton                         SOUTHWEST
# 406       Benton                              COLE
# 407       Benton                           LINDSEY
# 408       Benton                             UNION
# 409       Benton                               TOM
# 410       Benton                 FRISTOE/ALEXANDER
# 1610       Cedar                             BOX 1
# 1611       Cedar                             BOX 2
# 1612       Cedar                     CEDAR SPRINGS
# 1613       Cedar                        WASHINGTON
# ...

# %%
randolphtest = no_provisional[(no_provisional['county_name'] == 'Randolph')
                        & (no_provisional['office_title'] == 'State Representative - District 128')

                    ]
