# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("/Users/ashlynohara/Desktop/cleanmopython/cleanmissouri/data.csv")
# Out:
#       county_name precinct_name                    office_title  \
# 0           Adair   SOUTHWEST 1     State Senator - District 18
# 1           Adair   SOUTHEAST 2     State Senator - District 18
# 2           Adair   SOUTHEAST 3     State Senator - District 18
# 3           Adair   SOUTHEAST 4     State Senator - District 18
# 4           Adair   NORTHEAST 5     State Senator - District 18
# ...           ...           ...                             ...
# 13698      Wright     HARTVILLE  Constitutional Amendment No. 1
# 13699      Wright  LITTLE CREEK  Constitutional Amendment No. 1
# 13700      Wright         MANES  Constitutional Amendment No. 1
# 13701      Wright   GROVESPRING  Constitutional Amendment No. 1
# 13702      Wright      ABSENTEE  Constitutional Amendment No. 1
#
#       candidate_ballot_name  yes_votes  no_votes  Unnamed: 6  Unnamed: 7
# 0          Cindy O'Laughlin        283       NaN         NaN         NaN
# 1          Cindy O'Laughlin        635       NaN         NaN         NaN
# 2          Cindy O'Laughlin        194       NaN         NaN         NaN
# 3          Cindy O'Laughlin        325       NaN         NaN         NaN
# 4          Cindy O'Laughlin        396       NaN         NaN         NaN
# ...                     ...        ...       ...         ...         ...
# 13698                   NaN        300     399.0         NaN         NaN
# 13699                   NaN        164     193.0         NaN         NaN
# 13700                   NaN        115     208.0         NaN         NaN
# 13701                   NaN        230     358.0         NaN         NaN
# 13702                   NaN        170     182.0         NaN         NaN
#
# [13703 rows x 8 columns]

# %%
original_data = pd.read_csv("/Users/ashlynohara/Desktop/cleanmopython/cleanmissouri/data.csv")

# %%
no_absentee = original_data.loc[original_data['precinct_name'] != 'ABSENTEE']

# %%
no_federal = no_absentee.loc[(no_absentee['precinct_name'] != 'FEDERAL')]

# %%
no_provisional = no_federal.loc[(no_absentee['precinct_name'] != 'PROVISIONAL')]

# %%
house1 = no_provisional[(no_provisional['office_title'] == 'State Representative - District 1')
                       | (no_provisional['office_title'] == 'Constitutional Amendment No. 1')]

# %%
onehouse = house1[(house1['county_name'] == "Atchison")
                | (house1['county_name'] == "Holt")
                | (house1['county_name'] == "Nodaway")
                | (house1['county_name'] == "Worth")
               ]

# %%
onecandidate = onehouse[(onehouse['candidate_ballot_name'] != "Paul Taylor")]

# %%
onecandidate
# Out:
#       county_name               precinct_name  \
# 144      Atchison                      TARKIO
# 145      Atchison                   ROCK PORT
# 146      Atchison                     FAIRFAX
# 147      Atchison                    WESTBORO
# 148      Atchison                      WATSON
# 156      Atchison                      TARKIO
# 157      Atchison                   ROCK PORT
# 158      Atchison                     FAIRFAX
# 159      Atchison                    WESTBORO
# 160      Atchison                      WATSON
# 4082         Holt                   NORTHWEST
# 4083         Holt                   NORTHEAST
# 4084         Holt                     CENTRAL
# 4085         Holt         SOUTHEAST-SOUTHWEST
# 4092         Holt                   NORTHWEST
# 4093         Holt                   NORTHEAST
# 4094         Holt                     CENTRAL
# 4095         Holt         SOUTHEAST-SOUTHWEST
# 7464      Nodaway        ATCHISON (CLEARMONT)
# 7465      Nodaway             GRANT (BARNARD)
# 7466      Nodaway             GREEN (QUITMAN)
# 7467      Nodaway           HOPKINS (HOPKINS)
# 7468      Nodaway             HUGHES (GRAHAM)
# 7469      Nodaway      INDEPENDENCE (PARNELL)
# 7470      Nodaway         JACKSON (RAVENWOOD)
# 7471      Nodaway  JEFFERSON (CONCEPTION JCT)
# 7472      Nodaway              LINCOLN (ELMO)
# 7473      Nodaway           MONROE (SKIDMORE)
# 7474      Nodaway          NODAWAY (BURL JCT)
# 7475      Nodaway           UNION (PICKERING)
# 7476      Nodaway       WASHINGTON (GUILFORD)
# 7477      Nodaway                 WHITE CLOUD
# 7478      Nodaway               POLK A-POLK D
# 7479      Nodaway                      POLK E
# 7480      Nodaway               POLK B-POLK C
# 7540      Nodaway        ATCHISON (CLEARMONT)
# 7541      Nodaway             GRANT (BARNARD)
# 7542      Nodaway             GREEN (QUITMAN)
# 7543      Nodaway           HOPKINS (HOPKINS)
# 7544      Nodaway             HUGHES (GRAHAM)
# 7545      Nodaway      INDEPENDENCE (PARNELL)
# 7546      Nodaway         JACKSON (RAVENWOOD)
# 7547      Nodaway  JEFFERSON (CONCEPTION JCT)
# 7548      Nodaway              LINCOLN (ELMO)
# 7549      Nodaway           MONROE (SKIDMORE)
# 7550      Nodaway          NODAWAY (BURL JCT)
# 7551      Nodaway           UNION (PICKERING)
# 7552      Nodaway       WASHINGTON (GUILFORD)
# 7553      Nodaway                 WHITE CLOUD
# 7554      Nodaway               POLK A-POLK D
# 7555      Nodaway                      POLK E
# 7556      Nodaway               POLK B-POLK C
# 13643       Worth                       ALLEN
# 13644       Worth              EAST FLETCHALL
# 13645       Worth                      GREENE
# 13646       Worth                 MIDDLE FORK
# 13647       Worth                       SMITH
# 13648       Worth              WEST FLETCHALL
# 13649       Worth                  WEST UNION
# 13675       Worth                       ALLEN
# 13676       Worth              EAST FLETCHALL
# 13677       Worth                      GREENE
# 13678       Worth                 MIDDLE FORK
# 13679       Worth                       SMITH
# 13680       Worth              WEST FLETCHALL
# 13681       Worth                  WEST UNION
#
#                             office_title candidate_ballot_name  yes_votes  \
# 144    State Representative - District 1         Allen Andrews        520
# 145    State Representative - District 1         Allen Andrews        646
# 146    State Representative - District 1         Allen Andrews        378
# 147    State Representative - District 1         Allen Andrews        121
# 148    State Representative - District 1         Allen Andrews         50
# 156       Constitutional Amendment No. 1                   NaN        329
# 157       Constitutional Amendment No. 1                   NaN        431
# 158       Constitutional Amendment No. 1                   NaN        203
# 159       Constitutional Amendment No. 1                   NaN         69
# 160       Constitutional Amendment No. 1                   NaN         37
# 4082   State Representative - District 1         Allen Andrews        178
# 4083   State Representative - District 1         Allen Andrews        137
# 4084   State Representative - District 1         Allen Andrews        588
# 4085   State Representative - District 1         Allen Andrews        633
# 4092      Constitutional Amendment No. 1                   NaN        134
# 4093      Constitutional Amendment No. 1                   NaN         59
# 4094      Constitutional Amendment No. 1                   NaN        250
# 4095      Constitutional Amendment No. 1                   NaN        333
# 7464   State Representative - District 1         Allen Andrews        123
# 7465   State Representative - District 1         Allen Andrews        198
# 7466   State Representative - District 1         Allen Andrews         73
# 7467   State Representative - District 1         Allen Andrews        160
# 7468   State Representative - District 1         Allen Andrews        174
# 7469   State Representative - District 1         Allen Andrews         91
# 7470   State Representative - District 1         Allen Andrews        349
# 7471   State Representative - District 1         Allen Andrews        224
# 7472   State Representative - District 1         Allen Andrews        131
# 7473   State Representative - District 1         Allen Andrews        137
# 7474   State Representative - District 1         Allen Andrews        221
# 7475   State Representative - District 1         Allen Andrews        146
# 7476   State Representative - District 1         Allen Andrews        118
# 7477   State Representative - District 1         Allen Andrews        174
# 7478   State Representative - District 1         Allen Andrews       1139
# 7479   State Representative - District 1         Allen Andrews        492
# 7480   State Representative - District 1         Allen Andrews       1343
# 7540      Constitutional Amendment No. 1                   NaN         84
# 7541      Constitutional Amendment No. 1                   NaN        132
# 7542      Constitutional Amendment No. 1                   NaN         42
# 7543      Constitutional Amendment No. 1                   NaN        113
# 7544      Constitutional Amendment No. 1                   NaN         72
# 7545      Constitutional Amendment No. 1                   NaN         61
# 7546      Constitutional Amendment No. 1                   NaN        170
# 7547      Constitutional Amendment No. 1                   NaN        145
# 7548      Constitutional Amendment No. 1                   NaN         62
# 7549      Constitutional Amendment No. 1                   NaN         84
# 7550      Constitutional Amendment No. 1                   NaN        150
# 7551      Constitutional Amendment No. 1                   NaN         74
# 7552      Constitutional Amendment No. 1                   NaN         50
# 7553      Constitutional Amendment No. 1                   NaN         99
# 7554      Constitutional Amendment No. 1                   NaN       1017
# 7555      Constitutional Amendment No. 1                   NaN        295
# 7556      Constitutional Amendment No. 1                   NaN       1039
# 13643  State Representative - District 1         Allen Andrews         61
# 13644  State Representative - District 1         Allen Andrews        144
# 13645  State Representative - District 1         Allen Andrews         73
# 13646  State Representative - District 1         Allen Andrews         62
# 13647  State Representative - District 1         Allen Andrews         72
# 13648  State Representative - District 1         Allen Andrews        190
# 13649  State Representative - District 1         Allen Andrews        125
# 13675     Constitutional Amendment No. 1                   NaN         25
# 13676     Constitutional Amendment No. 1                   NaN         77
# 13677     Constitutional Amendment No. 1                   NaN         23
# 13678     Constitutional Amendment No. 1                   NaN         28
# 13679     Constitutional Amendment No. 1                   NaN         37
# 13680     Constitutional Amendment No. 1                   NaN         86
# 13681     Constitutional Amendment No. 1                   NaN         53
#
#        no_votes  Unnamed: 6  Unnamed: 7
# 144         NaN         NaN         NaN
# 145         NaN         NaN         NaN
# 146         NaN         NaN         NaN
# 147         NaN         NaN         NaN
# 148         NaN         NaN         NaN
# 156       289.0         NaN         NaN
# 157       335.0         NaN         NaN
# 158       241.0         NaN         NaN
# 159        76.0         NaN         NaN
# 160        30.0         NaN         NaN
# 4082        NaN         NaN         NaN
# 4083        NaN         NaN         NaN
# 4084        NaN         NaN         NaN
# 4085        NaN         NaN         NaN
# 4092       81.0         NaN         NaN
# 4093      101.0         NaN         NaN
# 4094      389.0         NaN         NaN
# 4095      429.0         NaN         NaN
# 7464        NaN         NaN         NaN
# 7465        NaN         NaN         NaN
# 7466        NaN         NaN         NaN
# 7467        NaN         NaN         NaN
# 7468        NaN         NaN         NaN
# 7469        NaN         NaN         NaN
# 7470        NaN         NaN         NaN
# 7471        NaN         NaN         NaN
# 7472        NaN         NaN         NaN
# 7473        NaN         NaN         NaN
# 7474        NaN         NaN         NaN
# 7475        NaN         NaN         NaN
# 7476        NaN         NaN         NaN
# 7477        NaN         NaN         NaN
# 7478        NaN         NaN         NaN
# 7479        NaN         NaN         NaN
# 7480        NaN         NaN         NaN
# 7540       75.0         NaN         NaN
# 7541      113.0         NaN         NaN
# 7542       55.0         NaN         NaN
# 7543      106.0         NaN         NaN
# 7544      120.0         NaN         NaN
# 7545       50.0         NaN         NaN
# 7546      216.0         NaN         NaN
# 7547      147.0         NaN         NaN
# 7548       88.0         NaN         NaN
# 7549       93.0         NaN         NaN
# 7550      135.0         NaN         NaN
# 7551       96.0         NaN         NaN
# 7552       89.0         NaN         NaN
# 7553      103.0         NaN         NaN
# 7554      696.0         NaN         NaN
# 7555      290.0         NaN         NaN
# 7556      756.0         NaN         NaN
# 13643       NaN         NaN         NaN
# 13644       NaN         NaN         NaN
# 13645       NaN         NaN         NaN
# 13646       NaN         NaN         NaN
# 13647       NaN         NaN         NaN
# 13648       NaN         NaN         NaN
# 13649       NaN         NaN         NaN
# 13675      45.0         NaN         NaN
# 13676      78.0         NaN         NaN
# 13677      53.0         NaN         NaN
# 13678      50.0         NaN         NaN
# 13679      44.0         NaN         NaN
# 13680     116.0         NaN         NaN
# 13681      76.0         NaN         NaN

# %%
justa1 = onecandidate[(onecandidate['office_title'] == "Constitutional Amendment No. 1")]

# %%
justa1
# Out:
#       county_name               precinct_name                    office_title  \
# 156      Atchison                      TARKIO  Constitutional Amendment No. 1
# 157      Atchison                   ROCK PORT  Constitutional Amendment No. 1
# 158      Atchison                     FAIRFAX  Constitutional Amendment No. 1
# 159      Atchison                    WESTBORO  Constitutional Amendment No. 1
# 160      Atchison                      WATSON  Constitutional Amendment No. 1
# 4092         Holt                   NORTHWEST  Constitutional Amendment No. 1
# 4093         Holt                   NORTHEAST  Constitutional Amendment No. 1
# 4094         Holt                     CENTRAL  Constitutional Amendment No. 1
# 4095         Holt         SOUTHEAST-SOUTHWEST  Constitutional Amendment No. 1
# 7540      Nodaway        ATCHISON (CLEARMONT)  Constitutional Amendment No. 1
# 7541      Nodaway             GRANT (BARNARD)  Constitutional Amendment No. 1
# 7542      Nodaway             GREEN (QUITMAN)  Constitutional Amendment No. 1
# 7543      Nodaway           HOPKINS (HOPKINS)  Constitutional Amendment No. 1
# 7544      Nodaway             HUGHES (GRAHAM)  Constitutional Amendment No. 1
# 7545      Nodaway      INDEPENDENCE (PARNELL)  Constitutional Amendment No. 1
# 7546      Nodaway         JACKSON (RAVENWOOD)  Constitutional Amendment No. 1
# 7547      Nodaway  JEFFERSON (CONCEPTION JCT)  Constitutional Amendment No. 1
# 7548      Nodaway              LINCOLN (ELMO)  Constitutional Amendment No. 1
# 7549      Nodaway           MONROE (SKIDMORE)  Constitutional Amendment No. 1
# 7550      Nodaway          NODAWAY (BURL JCT)  Constitutional Amendment No. 1
# 7551      Nodaway           UNION (PICKERING)  Constitutional Amendment No. 1
# 7552      Nodaway       WASHINGTON (GUILFORD)  Constitutional Amendment No. 1
# 7553      Nodaway                 WHITE CLOUD  Constitutional Amendment No. 1
# 7554      Nodaway               POLK A-POLK D  Constitutional Amendment No. 1
# 7555      Nodaway                      POLK E  Constitutional Amendment No. 1
# 7556      Nodaway               POLK B-POLK C  Constitutional Amendment No. 1
# 13675       Worth                       ALLEN  Constitutional Amendment No. 1
# 13676       Worth              EAST FLETCHALL  Constitutional Amendment No. 1
# 13677       Worth                      GREENE  Constitutional Amendment No. 1
# 13678       Worth                 MIDDLE FORK  Constitutional Amendment No. 1
# 13679       Worth                       SMITH  Constitutional Amendment No. 1
# 13680       Worth              WEST FLETCHALL  Constitutional Amendment No. 1
# 13681       Worth                  WEST UNION  Constitutional Amendment No. 1
#
#       candidate_ballot_name  yes_votes  no_votes  Unnamed: 6  Unnamed: 7
# 156                     NaN        329     289.0         NaN         NaN
# 157                     NaN        431     335.0         NaN         NaN
# 158                     NaN        203     241.0         NaN         NaN
# 159                     NaN         69      76.0         NaN         NaN
# 160                     NaN         37      30.0         NaN         NaN
# 4092                    NaN        134      81.0         NaN         NaN
# 4093                    NaN         59     101.0         NaN         NaN
# 4094                    NaN        250     389.0         NaN         NaN
# 4095                    NaN        333     429.0         NaN         NaN
# 7540                    NaN         84      75.0         NaN         NaN
# 7541                    NaN        132     113.0         NaN         NaN
# 7542                    NaN         42      55.0         NaN         NaN
# 7543                    NaN        113     106.0         NaN         NaN
# 7544                    NaN         72     120.0         NaN         NaN
# 7545                    NaN         61      50.0         NaN         NaN
# 7546                    NaN        170     216.0         NaN         NaN
# 7547                    NaN        145     147.0         NaN         NaN
# 7548                    NaN         62      88.0         NaN         NaN
# 7549                    NaN         84      93.0         NaN         NaN
# 7550                    NaN        150     135.0         NaN         NaN
# 7551                    NaN         74      96.0         NaN         NaN
# 7552                    NaN         50      89.0         NaN         NaN
# 7553                    NaN         99     103.0         NaN         NaN
# 7554                    NaN       1017     696.0         NaN         NaN
# 7555                    NaN        295     290.0         NaN         NaN
# 7556                    NaN       1039     756.0         NaN         NaN
# 13675                   NaN         25      45.0         NaN         NaN
# 13676                   NaN         77      78.0         NaN         NaN
# 13677                   NaN         23      53.0         NaN         NaN
# 13678                   NaN         28      50.0         NaN         NaN
# 13679                   NaN         37      44.0         NaN         NaN
# 13680                   NaN         86     116.0         NaN         NaN
# 13681                   NaN         53      76.0         NaN         NaN

# %%
justa1.yes_votes.sum()
# Out:
# 5863

# %%
h1yes = justa1.yes_votes.sum()

# %%
justa1.no_votes.sum()
# Out:
# 5661.0

# %%
h1no = justa1.no_votes.sum()

# %%
house_district1_percentage = h1yes / (h1yes + h1no)

# %%
house_district1_percentage * 100
# Out:
# 50.876431794515796

# %%
pd.set_option('display.max_rows', None)

# %%
house1.yes_votes.sum()
# Out:
# 1388066

# %% [markdown]
# "9,271" Verified in Microsoft Excel

# %%
house2 = no_provisional[(no_provisional['office_title'] == 'State Representative - District 2')]

# %%
house2
# Out:
#      county_name           precinct_name                       office_title  \
# 2769     Daviess                ALTAMONT  State Representative - District 2
# 2770     Daviess                GALLATIN  State Representative - District 2
# 2771     Daviess                 JAMESON  State Representative - District 2
# 2772     Daviess               JAMESPORT  State Representative - District 2
# 2773     Daviess             PATTONSBURG  State Representative - District 2
# 2774     Daviess                 WINSTON  State Representative - District 2
# 2801     De Kalb                   ADAMS  State Representative - District 2
# 2802     De Kalb                  COLFAX  State Representative - District 2
# 2803     De Kalb             GRAND RIVER  State Representative - District 2
# 2804     De Kalb                    POLK  State Representative - District 2
# 2805     De Kalb                 SHERMAN  State Representative - District 2
# 2806     De Kalb        NORTH WASHINGTON  State Representative - District 2
# 2807     De Kalb        SOUTH WASHINGTON  State Representative - District 2
# 2808     De Kalb    JUNE CONLEY BUILDING  State Representative - District 2
# 3384      Gentry  ATHENS NORTH AND SOUTH  State Representative - District 2
# 3385      Gentry            BOGLE GENTRY  State Representative - District 2
# 3386      Gentry    COOPER EAST AND WEST  State Representative - District 2
# 3387      Gentry       COOPER DARLINGTON  State Representative - District 2
# 3388      Gentry         HOWARD LONESTAR  State Representative - District 2
# 3389      Gentry         HUGGINS CARMACK  State Representative - District 2
# 3390      Gentry      JACKSON EAST &WEST  State Representative - District 2
# 3391      Gentry           MILLER BERLIN  State Representative - District 2
# 3392      Gentry           MILLER MCFALL  State Representative - District 2
# 3393      Gentry         WILSON ALANTHUS  State Representative - District 2
# 3973    Harrison                 BETHANY  State Representative - District 2
# 3974    Harrison              CAINSVILLE  State Representative - District 2
# 3975    Harrison             GILMAN CITY  State Representative - District 2
# 3976    Harrison              EAGLEVILLE  State Representative - District 2
# 3977    Harrison             NEW HAMPTON  State Representative - District 2
# 3978    Harrison                RIDGEWAY  State Representative - District 2
#
#      candidate_ballot_name  yes_votes  no_votes  Unnamed: 6  Unnamed: 7
# 2769          J. Eggleston        483       NaN         NaN         NaN
# 2770          J. Eggleston        711       NaN         NaN         NaN
# 2771          J. Eggleston        172       NaN         NaN         NaN
# 2772          J. Eggleston        332       NaN         NaN         NaN
# 2773          J. Eggleston        340       NaN         NaN         NaN
# 2774          J. Eggleston        413       NaN         NaN         NaN
# 2801          J. Eggleston        220       NaN         NaN         NaN
# 2802          J. Eggleston        263       NaN         NaN         NaN
# 2803          J. Eggleston        662       NaN         NaN         NaN
# 2804          J. Eggleston        279       NaN         NaN         NaN
# 2805          J. Eggleston        199       NaN         NaN         NaN
# 2806          J. Eggleston        243       NaN         NaN         NaN
# 2807          J. Eggleston        451       NaN         NaN         NaN
# 2808          J. Eggleston        815       NaN         NaN         NaN
# 3384          J. Eggleston        674       NaN         NaN         NaN
# 3385          J. Eggleston         70       NaN         NaN         NaN
# 3386          J. Eggleston        514       NaN         NaN         NaN
# 3387          J. Eggleston         58       NaN         NaN         NaN
# 3388          J. Eggleston         44       NaN         NaN         NaN
# 3389          J. Eggleston         59       NaN         NaN         NaN
# 3390          J. Eggleston        416       NaN         NaN         NaN
# 3391          J. Eggleston         87       NaN         NaN         NaN
# 3392          J. Eggleston         65       NaN         NaN         NaN
# 3393          J. Eggleston         70       NaN         NaN         NaN
# 3973          J. Eggleston       1003       NaN         NaN         NaN
# 3974          J. Eggleston        217       NaN         NaN         NaN
# 3975          J. Eggleston        203       NaN         NaN         NaN
# 3976          J. Eggleston        342       NaN         NaN         NaN
# 3977          J. Eggleston        244       NaN         NaN         NaN
# 3978          J. Eggleston        211       NaN         NaN         NaN

# %%
house2
# Out:
#      county_name           precinct_name                       office_title  \
# 2769     Daviess                ALTAMONT  State Representative - District 2
# 2770     Daviess                GALLATIN  State Representative - District 2
# 2771     Daviess                 JAMESON  State Representative - District 2
# 2772     Daviess               JAMESPORT  State Representative - District 2
# 2773     Daviess             PATTONSBURG  State Representative - District 2
# 2774     Daviess                 WINSTON  State Representative - District 2
# 2801     De Kalb                   ADAMS  State Representative - District 2
# 2802     De Kalb                  COLFAX  State Representative - District 2
# 2803     De Kalb             GRAND RIVER  State Representative - District 2
# 2804     De Kalb                    POLK  State Representative - District 2
# 2805     De Kalb                 SHERMAN  State Representative - District 2
# 2806     De Kalb        NORTH WASHINGTON  State Representative - District 2
# 2807     De Kalb        SOUTH WASHINGTON  State Representative - District 2
# 2808     De Kalb    JUNE CONLEY BUILDING  State Representative - District 2
# 3384      Gentry  ATHENS NORTH AND SOUTH  State Representative - District 2
# 3385      Gentry            BOGLE GENTRY  State Representative - District 2
# 3386      Gentry    COOPER EAST AND WEST  State Representative - District 2
# 3387      Gentry       COOPER DARLINGTON  State Representative - District 2
# 3388      Gentry         HOWARD LONESTAR  State Representative - District 2
# 3389      Gentry         HUGGINS CARMACK  State Representative - District 2
# 3390      Gentry      JACKSON EAST &WEST  State Representative - District 2
# 3391      Gentry           MILLER BERLIN  State Representative - District 2
# 3392      Gentry           MILLER MCFALL  State Representative - District 2
# 3393      Gentry         WILSON ALANTHUS  State Representative - District 2
# 3973    Harrison                 BETHANY  State Representative - District 2
# 3974    Harrison              CAINSVILLE  State Representative - District 2
# 3975    Harrison             GILMAN CITY  State Representative - District 2
# 3976    Harrison              EAGLEVILLE  State Representative - District 2
# 3977    Harrison             NEW HAMPTON  State Representative - District 2
# 3978    Harrison                RIDGEWAY  State Representative - District 2
#
#      candidate_ballot_name  yes_votes  no_votes  Unnamed: 6  Unnamed: 7
# 2769          J. Eggleston        483       NaN         NaN         NaN
# 2770          J. Eggleston        711       NaN         NaN         NaN
# 2771          J. Eggleston        172       NaN         NaN         NaN
# 2772          J. Eggleston        332       NaN         NaN         NaN
# 2773          J. Eggleston        340       NaN         NaN         NaN
# 2774          J. Eggleston        413       NaN         NaN         NaN
# 2801          J. Eggleston        220       NaN         NaN         NaN
# 2802          J. Eggleston        263       NaN         NaN         NaN
# 2803          J. Eggleston        662       NaN         NaN         NaN
# 2804          J. Eggleston        279       NaN         NaN         NaN
# 2805          J. Eggleston        199       NaN         NaN         NaN
# 2806          J. Eggleston        243       NaN         NaN         NaN
# 2807          J. Eggleston        451       NaN         NaN         NaN
# 2808          J. Eggleston        815       NaN         NaN         NaN
# 3384          J. Eggleston        674       NaN         NaN         NaN
# 3385          J. Eggleston         70       NaN         NaN         NaN
# 3386          J. Eggleston        514       NaN         NaN         NaN
# 3387          J. Eggleston         58       NaN         NaN         NaN
# 3388          J. Eggleston         44       NaN         NaN         NaN
# 3389          J. Eggleston         59       NaN         NaN         NaN
# 3390          J. Eggleston        416       NaN         NaN         NaN
# 3391          J. Eggleston         87       NaN         NaN         NaN
# 3392          J. Eggleston         65       NaN         NaN         NaN
# 3393          J. Eggleston         70       NaN         NaN         NaN
# 3973          J. Eggleston       1003       NaN         NaN         NaN
# 3974          J. Eggleston        217       NaN         NaN         NaN
# 3975          J. Eggleston        203       NaN         NaN         NaN
# 3976          J. Eggleston        342       NaN         NaN         NaN
# 3977          J. Eggleston        244       NaN         NaN         NaN
# 3978          J. Eggleston        211       NaN         NaN         NaN
